# %%
import pandas as pd
matches = pd.read_csv('matches.csv', index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#   season             team
# 1   2024  Manchester City
# 3   2024  Manchester City
# 4   2024  Manchester City
# 5   2024  Manchester City
# 6   2024  Manchester City
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (1520, 28)

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 30    40
# Matchweek 23    40
# Matchweek 24    40
# Matchweek 25    40
# Matchweek 18    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 28    40
# Matchweek 31    40
# Matchweek 2     40
# Matchweek 32    40
# Matchweek 33    40
# Matchweek 29    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 34    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 20    40
# Matchweek 19    40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 7     40
# Matchweek 8     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 15    40
# Matchweek 16    40
# Matchweek 17    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                 int64
# ga                 int64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L   1   3
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L   3   4
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L   0   2
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L   1   3
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D   4   4
#
#            opponent  ...   fk  pk  pkatt  season             team target  \
# 1           Burnley  ...  0.0   0      0    2024  Manchester City      1
# 3     Newcastle Utd  ...  0.0   0      0    2024  Manchester City      1
# 4     Sheffield Utd  ...  2.0   0      1    2024  Manchester City      1
# 5            Fulham  ...  0.0   1      1    2024  Manchester City      1
# 6          West Ham  ...  1.0   0      0    2024  Manchester City      1
# ..              ...  ...  ...  ..    ...     ...              ...    ...
# 42    Newcastle Utd  ...  0.0   0      0    2023      Southampton      0
# 43  Nott'ham Forest  ...  0.0   1      1    2023      Southampton      0
# 44           Fulham  ...  0.0   0      0    2023      Southampton      0
# 45         Brighton  ...  1.0   0      0    2023      Southampton      0
# 46        Liverpool  ...  1.0   0      0    2023      Southampton      0
#
#    venue_code opp_code hour  day_code
# 1           0        5   20         4
# 3           1       16   20         5
# 4           0       18   14         6
# 5           1        9   15         5
# 6           0       21   15         5
# ..        ...      ...  ...       ...
# 42          0       16   14         6
# 43          0       17   20         0
# 44          1        9   15         5
# 45          0        4   14         6
# 46          1       12   16         6
#
# [1520 rows x 33 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2024-01-01']
test = matches[matches["date"] > '2024-01-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]
rf.fit(train[predictors], train["target"])
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.6229508196721312

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           168  61
# 1            77  60

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.49586776859504134

# %%
grouped_matches =matches.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
#            opponent  ...   fk  pk  pkatt  season             team target  \
# 1          West Ham  ...  1.0   1      1    2023  Manchester City      1
# 2       Bournemouth  ...  0.0   0      0    2023  Manchester City      1
# 3     Newcastle Utd  ...  1.0   0      0    2023  Manchester City      0
# 4    Crystal Palace  ...  0.0   0      0    2023  Manchester City      1
# 5   Nott'ham Forest  ...  0.0   0      0    2023  Manchester City      1
# ..              ...  ...  ...  ..    ...     ...              ...    ...
# 51  Nott'ham Forest  ...  1.0   0      0    2024  Manchester City      1
# 52           Wolves  ...  0.0   2      2    2024  Manchester City      1
# 53           Fulham  ...  0.0   1      1    2024  Manchester City      1
# 54        Tottenham  ...  0.0   1      1    2024  Manchester City      1
# 55         West Ham  ...  2.0   0      0    2024  Manchester City      1
#
#    venue_code opp_code hour  day_code
# 1           0       21   16         6
# 2           1        2   15         5
# 3           0       16   16         6
# 4           1        7   15         5
# 5           1       17   19         2
# ..        ...      ...  ...       ...
# 51          0       17   16         6
# 52          1       22   17         5
# 53          0        9   12         5
# 54          0       20   20         1
# 55          1       21   16         6
#
# [76 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W   3   0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W   6   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
#            opponent  ...  hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# 4    Crystal Palace  ...    15         5    3.000000    1.000000  17.666667
# 5   Nott'ham Forest  ...    19         2    3.666667    1.666667  19.333333
# 6       Aston Villa  ...    17         5    4.333333    1.666667  18.666667
# 9            Wolves  ...    12         5    3.666667    1.000000  16.000000
# 10   Manchester Utd  ...    14         6    3.333333    0.333333  15.333333
# ..              ...  ...   ...       ...         ...         ...        ...
# 51  Nott'ham Forest  ...    16         6    4.333333    1.000000  22.666667
# 52           Wolves  ...    17         5    3.666667    0.333333  20.333333
# 53           Fulham  ...    12         5    3.666667    0.333333  14.333333
# 54        Tottenham  ...    20         1    3.666667    0.333333  14.666667
# 55         West Ham  ...    16         6    3.666667    0.333333  13.333333
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 4     6.000000    17.466667   0.666667   0.333333       0.333333
# 5     7.333333    15.933333   0.333333   0.000000       0.000000
# 6     8.000000    15.033333   0.333333   0.000000       0.000000
# 9     6.000000    15.233333   0.333333   0.000000       0.000000
# 10    6.666667    17.000000   0.333333   0.000000       0.000000
# ..         ...          ...        ...        ...            ...
# 51    8.666667    16.666667   0.333333   0.333333       0.333333
# 52    7.666667    17.533333   0.666667   0.333333       0.333333
# 53    7.000000    17.000000   0.666667   0.666667       0.666667
# 54    7.666667    17.200000   0.333333   1.000000       1.000000
# 55    7.333333    15.800000   0.000000   1.333333       1.333333
#
# [73 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
# <ipython-input-312-acb6ae218f4d>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#                                  date   time            comp         round  \
# team
# Arsenal                 3  2022-08-27  17:30  Premier League   Matchweek 4
#                         4  2022-08-31  19:30  Premier League   Matchweek 5
#                         5  2022-09-04  16:30  Premier League   Matchweek 6
#                         7  2022-09-18  12:00  Premier League   Matchweek 8
#                         8  2022-10-01  12:30  Premier League   Matchweek 9
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 40 2024-04-24  19:45  Premier League  Matchweek 29
#                         41 2024-04-27  15:00  Premier League  Matchweek 35
#                         42 2024-05-04  17:30  Premier League  Matchweek 36
#                         43 2024-05-11  15:00  Premier League  Matchweek 37
#                         44 2024-05-19  16:00  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 3   Sat  Home      W   2   1           Fulham  ...
#                         4   Wed  Home      W   2   1      Aston Villa  ...
#                         5   Sun  Away      L   1   3   Manchester Utd  ...
#                         7   Sun  Away      W   3   0        Brentford  ...
#                         8   Sat  Home      W   3   1        Tottenham  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 40  Wed  Home      L   0   1      Bournemouth  ...
#                         41  Sat  Home      W   2   1       Luton Town  ...
#                         42  Sat  Away      L   1   5  Manchester City  ...
#                         43  Sat  Home      L   1   3   Crystal Palace  ...
#                         44  Sun  Away      L   0   2        Liverpool  ...
#
#                             hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# team
# Arsenal                 3     17         5    3.000000    0.666667  14.333333
#                         4     19         2    3.000000    1.000000  18.333333
#                         5     16         6    2.333333    0.666667  19.333333
#                         7     12         6    1.666667    1.666667  20.000000
#                         8     12         5    2.000000    1.333333  17.000000
# ...                          ...       ...         ...         ...        ...
# Wolverhampton Wanderers 40    19         2    1.000000    2.000000   9.666667
#                         41    15         5    0.666667    1.666667  10.333333
#                         42    17         5    0.666667    1.333333  11.000000
#                         43    15         5    1.000000    2.333333  10.000000
#                         44    16         6    1.333333    3.000000   9.666667
#
#                            sot_rolling dist_rolling fk_rolling pk_rolling  \
# team
# Arsenal                 3     5.000000    14.133333   0.333333   0.000000
#                         4     7.000000    14.433333   0.333333   0.000000
#                         5     7.333333    15.533333   0.666667   0.000000
#                         7     6.333333    16.800000   1.000000   0.000000
#                         8     6.000000    17.700000   0.666667   0.000000
# ...                                ...          ...        ...        ...
# Wolverhampton Wanderers 40    4.000000    20.533333   0.333333   0.333333
#                         41    3.333333    18.766667   0.000000   0.000000
#                         42    4.000000    19.666667   0.000000   0.000000
#                         43    3.333333    15.966667   0.000000   0.000000
#                         44    4.666667    14.133333   0.000000   0.000000
#
#                             pkatt_rolling
# team
# Arsenal                 3        0.000000
#                         4        0.000000
#                         5        0.000000
#                         7        0.000000
#                         8        0.000000
# ...                                   ...
# Wolverhampton Wanderers 40       0.333333
#                         41       0.000000
#                         42       0.000000
#                         43       0.000000
#                         44       0.000000
#
# [1451 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2
# 1    2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   2
# 2    2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L   1
# 3    2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W   3
# 4    2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W   3
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1446 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0
# 1447 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2
# 1448 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1
# 1449 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1
# 1450 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0
#
#       ga         opponent  ...  hour  day_code  gf_rolling  ga_rolling  \
# 0      1           Fulham  ...    17         5    3.000000    0.666667
# 1      1      Aston Villa  ...    19         2    3.000000    1.000000
# 2      3   Manchester Utd  ...    16         6    2.333333    0.666667
# 3      0        Brentford  ...    12         6    1.666667    1.666667
# 4      1        Tottenham  ...    12         5    2.000000    1.333333
# ...   ..              ...  ...   ...       ...         ...         ...
# 1446   1      Bournemouth  ...    19         2    1.000000    2.000000
# 1447   1       Luton Town  ...    15         5    0.666667    1.666667
# 1448   5  Manchester City  ...    17         5    0.666667    1.333333
# 1449   3   Crystal Palace  ...    15         5    1.000000    2.333333
# 1450   2        Liverpool  ...    16         6    1.333333    3.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0     14.333333    5.000000    14.133333   0.333333   0.000000       0.000000
# 1     18.333333    7.000000    14.433333   0.333333   0.000000       0.000000
# 2     19.333333    7.333333    15.533333   0.666667   0.000000       0.000000
# 3     20.000000    6.333333    16.800000   1.000000   0.000000       0.000000
# 4     17.000000    6.000000    17.700000   0.666667   0.000000       0.000000
# ...         ...         ...          ...        ...        ...            ...
# 1446   9.666667    4.000000    20.533333   0.333333   0.333333       0.333333
# 1447  10.333333    3.333333    18.766667   0.000000   0.000000       0.000000
# 1448  11.000000    4.000000    19.666667   0.000000   0.000000       0.000000
# 1449  10.000000    3.333333    15.966667   0.000000   0.000000       0.000000
# 1450   9.666667    4.666667    14.133333   0.000000   0.000000       0.000000
#
# [1451 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.5447154471544715

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.head(10)
# Out:
#     actual  predicted       date     team         opponent result
# 55       1          1 2024-01-20  Arsenal   Crystal Palace      W
# 56       1          1 2024-01-30  Arsenal  Nott'ham Forest      W
# 57       1          1 2024-02-04  Arsenal        Liverpool      W
# 58       1          0 2024-02-11  Arsenal         West Ham      W
# 59       1          0 2024-02-17  Arsenal          Burnley      W
# 60       1          1 2024-02-24  Arsenal    Newcastle Utd      W
# 61       1          1 2024-03-04  Arsenal    Sheffield Utd      W
# 62       1          1 2024-03-09  Arsenal        Brentford      W
# 63       0          0 2024-03-31  Arsenal  Manchester City      D
# 64       1          1 2024-04-03  Arsenal       Luton Town      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton",
              "Manchester United": "Manchester Utd",
              "Newcastle United": "Newcastle Utd",
              "Tottenham Hotspur": "Tottenham",
              "West Ham United": "West Ham",
              "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            1 2024-01-20                  Arsenal
# 1           1            1 2024-01-30                  Arsenal
# 2           1            1 2024-02-04                  Arsenal
# 3           1            0 2024-02-11                  Arsenal
# 4           1            0 2024-02-17                  Arsenal
# ..        ...          ...        ...                      ...
# 325         0            0 2024-04-24  Wolverhampton Wanderers
# 326         1            0 2024-04-27  Wolverhampton Wanderers
# 327         0            0 2024-05-04  Wolverhampton Wanderers
# 328         0            0 2024-05-11  Wolverhampton Wanderers
# 329         0            0 2024-05-19  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Crystal Palace        W    Arsenal         0            0
# 1    Nott'ham Forest        W    Arsenal         0            0
# 2          Liverpool        W    Arsenal         0            0
# 3           West Ham        W    Arsenal         0            0
# 4            Burnley        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 325      Bournemouth        L     Wolves         1            0
# 326       Luton Town        W     Wolves         0            0
# 327  Manchester City        L     Wolves         1            1
# 328   Crystal Palace        L     Wolves         1            1
# 329        Liverpool        L     Wolves         1            1
#
#                 team_y opponent_y result_y         new_team_y
# 0       Crystal Palace    Arsenal        L     Crystal Palace
# 1    Nottingham Forest    Arsenal        L  Nottingham Forest
# 2            Liverpool    Arsenal        L          Liverpool
# 3      West Ham United    Arsenal        L           West Ham
# 4              Burnley    Arsenal        L            Burnley
# ..                 ...        ...      ...                ...
# 325        Bournemouth     Wolves        W        Bournemouth
# 326         Luton Town     Wolves        L         Luton Town
# 327    Manchester City     Wolves        W    Manchester City
# 328     Crystal Palace     Wolves        W     Crystal Palace
# 329          Liverpool     Wolves        W          Liverpool
#
# [330 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    59
# 0    41
# Name: count, dtype: int64

# %%
59/100
# Out:
# 0.59
